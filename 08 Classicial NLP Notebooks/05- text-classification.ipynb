# %% [markdown]
# ### `Text Classification`

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100000)
from IPython.display import display # color
import os
import eli5 # weigts

# sklearn
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC # faster # vs SVC kernal 
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
# a helper for displaying the DataFrame
def highlight_col(x, df):
    # set by condition
    pos_mask = (df['label'] == 'pos')
    neg_mask = (df['label'] == 'neg')
    x = pd.DataFrame('', index=df.index, columns=df.columns)
    x.loc[pos_mask] = 'background-color: #e6ffe6'
    x.loc[neg_mask] = 'background-color: #ffe6e6'
    return x

# %% [markdown]
# * `Load the data` [Here](https://www.kaggle.com/datasets/mksaad/arabic-sentiment-twitter-corpus)

# %%
# read tsv files for train
TRAIN_POS_PATH = os.path.join(os.getcwd(), 'Data', 'train_Arabic_tweets_positive_20190413.tsv')
TRAIN_NEG_PATH = os.path.join(os.getcwd(), 'Data', 'train_Arabic_tweets_negative_20190413.tsv')

df_train_pos = pd.read_csv(TRAIN_POS_PATH, sep='\t', header=None)
df_train_neg = pd.read_csv(TRAIN_NEG_PATH, sep='\t', header=None)

# Concate both
df_train = pd.concat([df_train_pos, df_train_neg], ignore_index=True)
df_train.columns = ['label', 'tweet']

df_train.head()
# Out:
#   label  \
# 0   pos
# 1   pos
# 2   pos
# 3   pos
# 4   pos
#
#                                                                                                                 tweet
# 0                   نحن الذين يتحول كل ما نود أن نقوله إلى دعاء لله، لا تبحثوا فينا عن قوة، إننا مكسورون، القوة التي…
# 1                                         وفي النهاية لن يبقىٰ معك آحدإلا من رأىٰ الجمال في روحك أماالمنبهرون بالمظا…
# 2                                                                                                     من الخير نفسه 💛
# 3  #زلزل_الملعب_نصرنا_بيلعب كن عالي الهمه ولا ترضى بغير القمه مجرد ساعات لاستعادة الصداره💛💙 الوصول إلى القمه مهارة ت…
# 4                      الشيء الوحيد الذي وصلوا فيه للعالمية هو : المسيار ..! . ترى كانوا يشجعون ريال مدريد ضد النصر 🤣

# %%
# No need more for them after concatenating
del df_train_pos, df_train_neg

# %%
# See Highlited DF with my custom function
df_tmp = df_train.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_7ed3b_row0_col0, #T_7ed3b_row0_col1, #T_7ed3b_row1_col0, #T_7ed3b_row1_col1, #T_7ed3b_row3_col0, #T_7ed3b_row3_col1 {
#   background-color: #e6ffe6;
# }
# #T_7ed3b_row2_col0, #T_7ed3b_row2_col1, #T_7ed3b_row4_col0, #T_7ed3b_row4_col1 {
#   background-color: #ffe6e6;
# }
# </style>
# <table id="T_7ed3b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed3b_level0_row0" class="row_heading level0 row0" >8252</th>
#       <td id="T_7ed3b_row0_col0" class="data row0 col0" >pos</td>
#       <td id="T_7ed3b_row0_col1" class="data row0 col1" >يقول عز وجل ( لقد خلقنا الإنسان في أحسن تقويم ) ويقول ( و لقد كرمنا بني آدم ) لايجوز بعض الصفات التي لا تليق على ال…</td>
#     </tr>
#     <tr>
#       <th id="T_7ed3b_level0_row1" class="row_heading level0 row1" >15023</th>
#       <td id="T_7ed3b_row1_col0" class="data row1 col0" >pos</td>
#       <td id="T_7ed3b_row1_col1" class="data row1 col1" >جون جون 😍</td>
#     </tr>
#     <tr>
#       <th id="T_7ed3b_level0_row2" class="row_heading level0 row2" >31125</th>
#       <td id="T_7ed3b_row2_col0" class="data row2 col0" >neg</td>
#       <td id="T_7ed3b_row2_col1" class="data row2 col1" >فيديو مؤثر 💔 كي لاننسى ،، ولن ننسى ولن نغفر ،، نريد القصاص ، ماعايذين تخازل في اهم اللحظات الحاسمه ،، دمهم غالي ،…</td>
#     </tr>
#     <tr>
#       <th id="T_7ed3b_level0_row3" class="row_heading level0 row3" >21644</th>
#       <td id="T_7ed3b_row3_col0" class="data row3 col0" >pos</td>
#       <td id="T_7ed3b_row3_col1" class="data row3 col1" >عندما تحب أحدهم لا تخبره كثيرا عن ذلك الحب إجعله يراه .. 🍁 #تايه 💔 #اجمل_احساس_للدعم</td>
#     </tr>
#     <tr>
#       <th id="T_7ed3b_level0_row4" class="row_heading level0 row4" >40362</th>
#       <td id="T_7ed3b_row4_col0" class="data row4 col0" >neg</td>
#       <td id="T_7ed3b_row4_col1" class="data row4 col1" >💚🍃🌷📿 🥀 🥀 من السهل أن تضع يدك على فمك كي لآ. تتكلم ولكن من آلصعب أن تضع يدك على قلبك ك…</td>
#     </tr>
#   </tbody>
# </table>

# %%
# read tsv files for train
TEST_POS_PATH = os.path.join(os.getcwd(), 'Data', 'test_Arabic_tweets_positive_20190413.tsv')
TEST_NEG_PATH = os.path.join(os.getcwd(), 'Data', 'test_Arabic_tweets_negative_20190413.tsv')

df_test_pos = pd.read_csv(TEST_POS_PATH, sep='\t', header=None)
df_test_neg = pd.read_csv(TEST_NEG_PATH, sep='\t', header=None)

# Concate both
df_test = pd.concat([df_test_pos, df_test_neg], ignore_index=True)
df_test.columns = ['label', 'tweet']

df_test.head()
# Out:
#   label  \
# 0   pos
# 1   pos
# 2   pos
# 3   pos
# 4   pos
#
#                                                                                                                             tweet
# 0               #الهلال_الاهلي فوز هلالي مهم الحمد لله 💙 زوران كان بيسلم المباراة بعد تبديل كارييو بإنتظار الإتحاد بكرة يارب يار…
# 1                                                                                                            صباحك خيرات ومسرات 🌸
# 2                     #تأمل قال الله ﷻ :- _*​﴿بواد غير ذي زرع ﴾*_ 💫💫 ✍ " ~ومع ذلك هتف بالدعاء ﴿وارزقهم من الثمرات ﴾ مهماكانت ظرو…
# 3               😂😂 يا جدعان الرجاله اللي فوق ال دول خطر ع تويتر وربنا 😂مش اسلوب كل يومين يدخلي واحد قد جدي علشان يشقطني 😒 😹و عند…
# 4  رساله صباحيه : 💛 اللهم اسألك التوفيق في جميع امورنا واكتب لنا الفردوس نحن ووالدينا وجميع موتى المسلمين برحمتك يا ارحم الراحمين

# %%
# No need more for them after concatenating
del df_test_pos, df_test_neg

# %%
# See Highlited DF with my custom function
df_tmp = df_test.sample(5)
df_tmp.style.apply(lambda x: highlight_col(x, df_tmp), axis=None)
# Out:
# <style type="text/css">
# #T_5ff89_row0_col0, #T_5ff89_row0_col1, #T_5ff89_row1_col0, #T_5ff89_row1_col1, #T_5ff89_row2_col0, #T_5ff89_row2_col1, #T_5ff89_row4_col0, #T_5ff89_row4_col1 {
#   background-color: #e6ffe6;
# }
# #T_5ff89_row3_col0, #T_5ff89_row3_col1 {
#   background-color: #ffe6e6;
# }
# </style>
# <table id="T_5ff89_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ff89_level0_row0" class="row_heading level0 row0" >5586</th>
#       <td id="T_5ff89_row0_col0" class="data row0 col0" >pos</td>
#       <td id="T_5ff89_row0_col1" class="data row0 col1" >حسابات ملگية♛ 🌟🌟 مغردون مميزون.. لهم حضور أنيق وحروف رآقية 🌸 #حسابات_ملكية_تستحق_المتابعة …</td>
#     </tr>
#     <tr>
#       <th id="T_5ff89_level0_row1" class="row_heading level0 row1" >5164</th>
#       <td id="T_5ff89_row1_col0" class="data row1 col0" >pos</td>
#       <td id="T_5ff89_row1_col1" class="data row1 col1" >اسرع تحويلل وصلني من #ريهام_الخير_والعطاء الله يسعدها ويعوضها اضعافها 🖤 وكل متفاعل له نصيب معها ما يضيع حق…</td>
#     </tr>
#     <tr>
#       <th id="T_5ff89_level0_row2" class="row_heading level0 row2" >5643</th>
#       <td id="T_5ff89_row2_col0" class="data row2 col0" >pos</td>
#       <td id="T_5ff89_row2_col1" class="data row2 col1" >الشيء الوحيد الذي وصلوا فيه للعالمية هو : المسيار ..! . ترى كانوا يشجعون ريال مدريد ضد النصر 🤣</td>
#     </tr>
#     <tr>
#       <th id="T_5ff89_level0_row3" class="row_heading level0 row3" >10570</th>
#       <td id="T_5ff89_row3_col0" class="data row3 col0" >neg</td>
#       <td id="T_5ff89_row3_col1" class="data row3 col1" >وجهة نظر 😂😂 أنت شككت في (هدف ) و (طرد ) المختصين استندوا على مواد قانونية وليست حالات تقديرية فعلى ماذا استندت يا…</td>
#     </tr>
#     <tr>
#       <th id="T_5ff89_level0_row4" class="row_heading level0 row4" >3804</th>
#       <td id="T_5ff89_row4_col0" class="data row4 col0" >pos</td>
#       <td id="T_5ff89_row4_col1" class="data row4 col1" >❤تصبحوا على خير ❤</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ----

# %% [markdown]
# * `Baseline model (using pipeline)`

# %%
# Vectorizing and then model
vect = CountVectorizer(max_features=15000, encoding='utf-8') # only X ### encoding
clf = LogisticRegression(max_iter=10000) # may target be text # X and y

# combine them to a pipeline
pipe = Pipeline(steps=[
        ('vectorizer', vect),
        ('classifier', clf)
    ])

# fitting to train data # x and y for pipe
pipe.fit(df_train['tweet'], df_train['label'])
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(max_features=15000)),
#                 ('classifier', LogisticRegression(max_iter=10000))])

# %%
df_train['label'].value_counts()   # balanced dataset --> acc
# Out:
# pos    22761
# neg    22514
# Name: label, dtype: int64

# %% [markdown]
# * `Test the Baseline`

# %%
# predict on test
y_pred_test = pipe.predict(df_test['tweet'])
print(f'Accuracy is {accuracy_score(df_test["label"], y_pred_test) * 100:.3f} %')
# Out:
# Accuracy is 77.231 %

# %% [markdown]
# * `Let's take a look inside the model`

# %%
eli5.show_weights(clf, vec=vect, top=20, feature_names=vect.get_feature_names_out())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.869
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الإخونج
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.569
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         برونو
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.445
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         وصباحك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.385
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         هالسنه
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.057
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الزرقاء
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.996
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ابريل
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.977
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         اللوك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.63%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.970
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         تعبر
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.966
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         حكمة
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.904
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         فيديو_الهلال
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.889
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         حفله_ديانا_حداد_بالكويت
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.888
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         الطيب
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 85.08%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 7738 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.91%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 7243 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 84.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.919
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         يستر
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.012
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         فهناك
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.039
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مؤلم
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.044
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         فاتني
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.233
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         أجباري_وليس_أختياري
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.234
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         مسلسل_ودك_يتكرر_برمضان
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.264
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         زعيم_تويتر_فولورز_اهلاوي
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.763
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         امطار_الشرقيه
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# * `Try our model on some tweets`

# %%
for _, row in df_test.sample(5).iterrows():
    print(f"True label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vect, top=10, feature_names=vect.get_feature_names_out()))
    print("--"*50)

# Green: Features that support the predicted class. These features increase the likelihood of the model predicting the shown class.
# Red: Features that support the opposite class. These features decrease the likelihood of the model predicting the shown class.
# Out:
# True label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.863</b>, score <b>1.842</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.094
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 3 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 94.71%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 3 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 94.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 92.25%); opacity: 0.82" title="0.143">لكل</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.84%); opacity: 0.85" title="0.339">حقبة</span><span style="opacity: 0.80"> زمان و </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.496">رجال</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.22%); opacity: 0.88" title="0.587">اللهم</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 71.84%); opacity: 0.92" title="0.906">أحفظ</span><span style="opacity: 0.80"> بلدي </span><span style="background-color: hsl(0, 100.00%, 89.67%); opacity: 0.83" title="-0.216">الكويت</span><span style="opacity: 0.80"> 🇰🇼 وشعبها من كل مكروه 💙 وراحم ابونا </span><span style="background-color: hsl(120, 100.00%, 64.46%); opacity: 0.97" title="1.264">الغالى</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.14%); opacity: 0.82" title="0.174">الشيخ</span><span style="opacity: 0.80"> جابر الاحمد من </span><span style="background-color: hsl(120, 100.00%, 84.30%); opacity: 0.85" title="0.393">يحب</span><span style="opacity: 0.80"> الم…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.886</b>, score <b>2.055</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.368
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 95.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 80.40%); opacity: 0.87" title="0.587">اللهم</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.36%); opacity: 0.83" title="0.213">اجعل</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.626">القرآن</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 85.59%); opacity: 0.85" title="0.378">العظيم</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 84.70%); opacity: 0.85" title="-0.412">ربيع</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.89%); opacity: 0.80" title="-0.024">قلبي</span><span style="opacity: 0.80"> 🍃</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.819</b>, score <b>-1.512</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.198
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">😂 </span><span style="background-color: hsl(0, 100.00%, 97.32%); opacity: 0.80" title="-0.025">من</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.166">حقه</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.73%); opacity: 0.80" title="0.019">يزعل</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.60%); opacity: 0.81" title="0.050">وين</span><span style="opacity: 0.80"> يحطهن </span><span style="background-color: hsl(0, 100.00%, 92.32%); opacity: 0.82" title="-0.111">في</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.95%); opacity: 0.82" title="0.098">أسبوع</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (probability <b>0.568</b>, score <b>0.275</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.588
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.588">الضوء</span><span style="opacity: 0.80"> اقوي ويجنن يابنات</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (probability <b>0.902</b>, score <b>-2.222</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.908
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 77.17%); opacity: 0.89" title="0.441">فكرة</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.10%); opacity: 0.81" title="0.035">انه</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.982">ماما</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 88.63%); opacity: 0.83" title="0.163">عامله</span><span style="opacity: 0.80"> محشي ملفوف </span><span style="background-color: hsl(120, 100.00%, 83.06%); opacity: 0.86" title="0.288">اليوم</span><span style="opacity: 0.80"> محزناننيي 💔</span>
#     </p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ----

# %% [markdown]
# * `Try Tfidf with some Processing`

# %%
# Using TFIDF and SVC in one pipeline
# char_wb: will generate character n-grams within each word separately and will not span across the boundaries of different word
vect = TfidfVectorizer(analyzer='char_wb', ngram_range=(3, 5), min_df=0.01, max_df=0.5, max_features=10000)
clf = LinearSVC() # may target text
pipe_tfidf = Pipeline(steps=[
        ('vectorizer', vect),
        ('classifier', clf)
    ])
pipe_tfidf.fit(df_train['tweet'], df_train['label'])
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='char_wb', max_df=0.5,
#                                  max_features=10000, min_df=0.01,
#                                  ngram_range=(3, 5))),
#                 ('classifier', LinearSVC())])

# %%
# predict on test
y_pred_test = pipe_tfidf.predict(df_test['tweet'])
print(f'Accuracy is {accuracy_score(df_test["label"], y_pred_test) * 100:.3f} %')
# Out:
# Accuracy is 83.811 %

# %%
for _, row in df_test.sample(5).iterrows():
    print(f"True label: {row['label']}")
    display(eli5.show_prediction(clf, row['tweet'], vec=vect, top=10, feature_names=vect.get_feature_names_out()))
    print("--"*50)
# Out:
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-1.600</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.900
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 31 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 18 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 93.63%); opacity: 0.81" title="-0.027">الكل</span><span style="opacity: 0.80">ية ك</span><span style="background-color: hsl(0, 100.00%, 92.83%); opacity: 0.82" title="-0.032">لها </span><span style="opacity: 0.80">خلصت ام</span><span style="background-color: hsl(120, 100.00%, 88.09%); opacity: 0.84" title="0.065">ت</span><span style="background-color: hsl(120, 100.00%, 81.76%); opacity: 0.87" title="0.120">حا</span><span style="background-color: hsl(120, 100.00%, 89.48%); opacity: 0.83" title="0.055">ن</span><span style="opacity: 0.80">ات و مريحةاسبوع في البيت و ناي</span><span style="background-color: hsl(0, 100.00%, 92.58%); opacity: 0.82" title="-0.033">مين </span><span style="opacity: 0.80">معادا</span><span style="background-color: hsl(0, 100.00%, 92.28%); opacity: 0.82" title="-0.035"> الد</span><span style="opacity: 0.80">فعة</span><span style="background-color: hsl(0, 100.00%, 91.26%); opacity: 0.82" title="-0.042"> الع</span><span style="background-color: hsl(120, 100.00%, 92.08%); opacity: 0.82" title="0.036">اق </span><span style="opacity: 0.80">بتاعتناا ..</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.369"> 😢</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-0.853</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.989
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 19 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 18 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="opacity: 0.80">ღ♬ . . أسلى مع طيفك الين إنتعش</span><span style="background-color: hsl(0, 100.00%, 95.43%); opacity: 0.81" title="-0.019">تك</span><span style="background-color: hsl(120, 100.00%, 90.07%); opacity: 0.83" title="0.057"> </span><span style="background-color: hsl(120, 100.00%, 91.16%); opacity: 0.82" title="0.049">ع</span><span style="background-color: hsl(120, 100.00%, 91.22%); opacity: 0.82" title="0.048">شا</span><span style="background-color: hsl(0, 100.00%, 93.96%); opacity: 0.81" title="-0.028">ن</span><span style="background-color: hsl(0, 100.00%, 88.57%); opacity: 0.83" title="-0.070"> </span><span style="opacity: 0.80">مااحس بغيا</span><span style="background-color: hsl(0, 100.00%, 92.26%); opacity: 0.82" title="-0.040">بك </span><span style="opacity: 0.80">على طول يا</span><span style="background-color: hsl(0, 100.00%, 90.53%); opacity: 0.83" title="-0.054">جع</span><span style="background-color: hsl(0, 100.00%, 86.80%); opacity: 0.84" title="-0.086">ل</span><span style="background-color: hsl(0, 100.00%, 93.32%); opacity: 0.82" title="-0.033">ها </span><span style="opacity: 0.80">في ذم</span><span style="background-color: hsl(0, 100.00%, 95.43%); opacity: 0.81" title="-0.019">تك </span><span style="opacity: 0.80">ماوحش</span><span style="background-color: hsl(0, 100.00%, 95.43%); opacity: 0.81" title="-0.019">تك</span><span style="background-color: hsl(120, 100.00%, 61.27%); opacity: 0.99" title="0.401"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.420">💔 </span><span style="opacity: 0.80">#تصميم</span><span style="background-color: hsl(120, 100.00%, 89.44%); opacity: 0.83" title="0.063">ي…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-1.377</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.002
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 11 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 14 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 99.26%); opacity: 0.80" title="0.001">بس </span><span style="opacity: 0.80">خلاص وقفت وخ</span><span style="background-color: hsl(0, 100.00%, 91.86%); opacity: 0.82" title="-0.045">را</span><span style="background-color: hsl(0, 100.00%, 96.03%); opacity: 0.81" title="-0.016"> </span><span style="background-color: hsl(120, 100.00%, 89.18%); opacity: 0.83" title="0.068">علي</span><span style="background-color: hsl(0, 100.00%, 98.52%); opacity: 0.80" title="-0.004"> </span><span style="background-color: hsl(120, 100.00%, 90.87%); opacity: 0.82" title="0.053">اذا</span><span style="opacity: 0.80"> س</span><span style="background-color: hsl(120, 100.00%, 89.79%); opacity: 0.83" title="0.063">ويت </span><span style="opacity: 0.80">فعا</span><span style="background-color: hsl(120, 100.00%, 92.04%); opacity: 0.82" title="0.044">ليه </span><span style="opacity: 0.80">مره ثانيه</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.440"> 😭</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: pos
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=pos
#
# </b>
#
#
#     (score <b>0.892</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 43 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 32 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.126
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-0.068">سح</span><span style="opacity: 0.80">ب على مبلغ مالي 💰 ل</span><span style="background-color: hsl(120, 100.00%, 77.57%); opacity: 0.89" title="0.030">متاب</span><span style="opacity: 0.80">عي #كشكول 👍🏻 المطلوب: ولا شي بس</span><span style="background-color: hsl(0, 100.00%, 80.41%); opacity: 0.87" title="-0.024"> ر</span><span style="background-color: hsl(120, 100.00%, 95.38%); opacity: 0.81" title="0.003">ت</span><span style="background-color: hsl(0, 100.00%, 79.24%); opacity: 0.88" title="-0.027">وي</span><span style="background-color: hsl(0, 100.00%, 96.46%); opacity: 0.81" title="-0.002">ت</span><span style="background-color: hsl(120, 100.00%, 84.33%); opacity: 0.85" title="0.018"> </span><span style="opacity: 0.80">🔁🔥 السحب من</span><span style="background-color: hsl(120, 100.00%, 71.42%); opacity: 0.92" title="0.042"> </span><span style="background-color: hsl(0, 100.00%, 95.43%); opacity: 0.81" title="-0.003">الر</span><span style="background-color: hsl(120, 100.00%, 78.70%); opacity: 0.88" title="0.028">ت</span><span style="background-color: hsl(0, 100.00%, 96.46%); opacity: 0.81" title="-0.002">ويت</span><span style="background-color: hsl(120, 100.00%, 84.33%); opacity: 0.85" title="0.018"> </span><span style="opacity: 0.80">في أي لحظة 😎 ✋🏻</span><span style="background-color: hsl(0, 100.00%, 80.47%); opacity: 0.87" title="-0.024"> #</span><span style="background-color: hsl(0, 100.00%, 88.89%); opacity: 0.83" title="-0.011">م</span><span style="background-color: hsl(120, 100.00%, 87.09%); opacity: 0.84" title="0.013">سا</span><span style="opacity: 0.80">بقات</span><span style="background-color: hsl(0, 100.00%, 80.47%); opacity: 0.87" title="-0.024"> #</span><span style="background-color: hsl(0, 100.00%, 88.89%); opacity: 0.83" title="-0.011">م</span><span style="background-color: hsl(120, 100.00%, 87.09%); opacity: 0.84" title="0.013">سا</span><span style="opacity: 0.80">بقات_كشكول</span><span style="background-color: hsl(0, 100.00%, 80.47%); opacity: 0.87" title="-0.024"> #</span><span style="background-color: hsl(0, 100.00%, 88.89%); opacity: 0.83" title="-0.011">م</span><span style="background-color: hsl(120, 100.00%, 87.09%); opacity: 0.84" title="0.013">سا</span><span style="opacity: 0.80">بقه</span>
#     </p>
# ----------------------------------------------------------------------------------------------------
# True label: neg
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=neg
#
# </b>
#
#
#     (score <b>-2.088</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.829
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 25 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 20 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 87.52%); opacity: 0.84" title="0.074">بد</span><span style="background-color: hsl(0, 100.00%, 91.65%); opacity: 0.82" title="-0.042">ايا</span><span style="opacity: 0.80">ت </span><span style="background-color: hsl(0, 100.00%, 95.30%); opacity: 0.81" title="-0.018">ا</span><span style="background-color: hsl(120, 100.00%, 90.47%); opacity: 0.83" title="0.051">لم</span><span style="background-color: hsl(120, 100.00%, 88.16%); opacity: 0.84" title="0.069">ل</span><span style="opacity: 0.80">وك🔥🔥</span><span style="background-color: hsl(120, 100.00%, 92.10%); opacity: 0.82" title="0.039"> #م</span><span style="opacity: 0.80">لوك</span><span style="background-color: hsl(120, 100.00%, 87.07%); opacity: 0.84" title="0.078">_الا</span><span style="opacity: 0.80">ضافات_ب</span><span style="background-color: hsl(120, 100.00%, 93.14%); opacity: 0.82" title="0.032">تويت</span><span style="opacity: 0.80">ر ي</span><span style="background-color: hsl(120, 100.00%, 93.98%); opacity: 0.81" title="0.026">موت</span><span style="background-color: hsl(0, 100.00%, 91.26%); opacity: 0.82" title="-0.045"> الغ</span><span style="opacity: 0.80">لا من قلة الوصل والتقدير مثل </span><span style="background-color: hsl(120, 100.00%, 93.98%); opacity: 0.81" title="0.026">موت</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.30%); opacity: 0.81" title="-0.018">الم</span><span style="opacity: 0.80">عروف لاصار به منه</span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="0.392"> 💔 </span><span style="opacity: 0.80">♨️♨️…</span>
#     </p>
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# * `Feel free to play with notebook explore different models with different datasets`

# %%
import joblib
joblib.dump(pipe_tfidf, 'model.pkl')
# Out:
# ['model.pkl']

# %% [markdown]
# ---
